# %%
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen

url = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20180827"

page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20180827" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div', 'tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=157243" title="당갈">당갈</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=167787" title="허스토리">허스토리</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=39636" title="지금, 만나러 갑니다">지금, 만나러 갑니다</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=136990" title="인크레더블 2">인크레더블 2</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=158191" title="1987">1987</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=175727" title="극장판 헬로카봇 : 백악기 시대">극장판 헬로카봇 : 백악기 시대</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=173019" title="명탐정 코난 : 제로의 집행인">명탐정 코난 : 제로의 집행인</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=172174" title="어느 가족">어느 가족</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=144379" title="러빙 빈센트">러빙 빈센트</a>
#  </div>, <div class="tit5">
# ...

# %%
soup.find_all('div', 'tit5')[0].a
# Out:
# <a href="/movie/bi/mi/basic.nhn?code=157243" title="당갈">당갈</a>

# %%
soup.find_all('div', 'tit5')[0].a.string
# Out:
# '당갈'

# %%
movie_name = [each.a.string for each in soup.find_all('div', 'tit5')]
movie_name
# Out:
# ['당갈',
#  '허스토리',
#  '지금, 만나러 갑니다',
#  '인크레더블 2',
#  '1987',
#  '극장판 헬로카봇 : 백악기 시대',
#  '명탐정 코난 : 제로의 집행인',
#  '어느 가족',
#  '러빙 빈센트',
#  '내 사랑',
#  '미션 임파서블: 폴아웃',
#  '맘마미아!2',
#  '어벤져스: 인피니티 워',
#  '너의 결혼식',
#  '그것만이 내 세상',
#  '바르다가 사랑한 얼굴들',
#  '소공녀',
#  '비포 선라이즈',
#  '극장판 도라에몽: 진구의 보물섬',
#  '신비아파트: 금빛 도깨비와 비밀의 동굴',
#  '바닷마을 다이어리',
#  '부르고뉴, 와인에서 찾은 인생',
#  '앤트맨과 와스프',
#  '걸어도 걸어도',
#  '안경',
#  '몬스터 호텔 3',
#  '아비정전',
#  '이별의 아침에 약속의 꽃을 장식하자',
#  '시카리오: 데이 오브 솔다도',
#  '탐정: 리턴즈',
#  '나를 차버린 스파이',
#  '카모메 식당',
#  '신은 죽지 않았다 3: 어둠 속의 빛',
#  '노인을 위한 나라는 없다',
#  '고양이를 빌려드립니다',
#  '파리로 가는 길',
#  '아이 엠 러브',
#  '한여름의 판타지아',
#  '세 번째 살인',
#  '신과함께-인과 연',
#  '콜 미 바이 유어 네임',
#  '킬링 디어',
#  '공작',
#  '메가로돈',
#  '조선명탐정: 흡혈괴마의 비밀',
#  '곤지암',
#  '목격자',
#  '인랑']

# %%
soup.find_all('td','point')
# Out:
# [<td class="point">9.52</td>,
#  <td class="point">9.35</td>,
#  <td class="point">9.34</td>,
#  <td class="point">9.27</td>,
#  <td class="point">9.25</td>,
#  <td class="point">9.24</td>,
#  <td class="point">9.23</td>,
#  <td class="point">9.22</td>,
#  <td class="point">9.19</td>,
#  <td class="point">9.17</td>,
#  <td class="point">9.14</td>,
#  <td class="point">9.07</td>,
#  <td class="point">8.95</td>,
#  <td class="point">8.94</td>,
#  <td class="point">8.92</td>,
#  <td class="point">8.91</td>,
#  <td class="point">8.88</td>,
#  <td class="point">8.88</td>,
#  <td class="point">8.78</td>,
#  <td class="point">8.76</td>,
#  <td class="point">8.74</td>,
#  <td class="point">8.71</td>,
#  <td class="point">8.66</td>,
#  <td class="point">8.64</td>,
#  <td class="point">8.60</td>,
#  <td class="point">8.59</td>,
#  <td class="point">8.51</td>,
#  <td class="point">8.49</td>,
#  <td class="point">8.48</td>,
#  <td class="point">8.44</td>,
#  <td class="point">8.38</td>,
# ...

# %%
soup.find_all('td', 'point')[0].string
# Out:
# '9.52'

# %%
movie_point = [each.string for each in soup.find_all('td', 'point')]
movie_point
# Out:
# ['9.52',
#  '9.35',
#  '9.34',
#  '9.27',
#  '9.25',
#  '9.24',
#  '9.23',
#  '9.22',
#  '9.19',
#  '9.17',
#  '9.14',
#  '9.07',
#  '8.95',
#  '8.94',
#  '8.92',
#  '8.91',
#  '8.88',
#  '8.88',
#  '8.78',
#  '8.76',
#  '8.74',
#  '8.71',
#  '8.66',
#  '8.64',
#  '8.60',
#  '8.59',
#  '8.51',
#  '8.49',
#  '8.48',
#  '8.44',
#  '8.38',
#  '8.38',
#  '8.37',
#  '8.20',
#  '8.08',
#  '7.90',
#  '7.89',
#  '7.83',
#  '7.78',
#  '7.73',
#  '7.55',
#  '7.16',
#  '6.87',
#  '6.73',
#  '6.65',
#  '6.47',
#  '5.66',
#  '3.87']

# %%
date = pd.date_range('2018.07.01', periods=35, freq='D')
date
# Out:
# DatetimeIndex(['2018-07-01', '2018-07-02', '2018-07-03', '2018-07-04',
#                '2018-07-05', '2018-07-06', '2018-07-07', '2018-07-08',
#                '2018-07-09', '2018-07-10', '2018-07-11', '2018-07-12',
#                '2018-07-13', '2018-07-14', '2018-07-15', '2018-07-16',
#                '2018-07-17', '2018-07-18', '2018-07-19', '2018-07-20',
#                '2018-07-21', '2018-07-22', '2018-07-23', '2018-07-24',
#                '2018-07-25', '2018-07-26', '2018-07-27', '2018-07-28',
#                '2018-07-29', '2018-07-30', '2018-07-31', '2018-08-01',
#                '2018-08-02', '2018-08-03', '2018-08-04'],
#               dtype='datetime64[ns]', freq='D')

# %%
date[0]
# Out:
# Timestamp('2018-07-01 00:00:00', freq='D')

# %%
date[0].strftime('%y-%m-%d')
# Out:
# '18-07-01'

# %%
date[0].strftime('%y.%m.%d')
# Out:
# '18.07.01'

# %%
date[0].strftime('%y%m%d')
# Out:
# '180701'

# %%
date[0].strftime('%Y%m%d')
# Out:
# '20180701'

# %%
import time

movie_date = []
movie_name = []
movie_point = []

# %%
for today in date:
    html = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20180827"
    response = urlopen(html.format(date = today.strftime("%Y%m%d")))
    soup = BeautifulSoup(response, "html.parser")
    
    movie_date.extend([today]*len(soup.find_all('td', 'point')))
    movie_name.extend([each.a.string for each in soup.find_all('div', 'tit5')])
    movie_point.extend([each.string for each in soup.find_all('td', 'point')])
    
print(str(today))
time.sleep(0.5)
# Out:
# 2018-08-04 00:00:00

# %%
len(movie_date), len(movie_name), len(movie_point)
# Out:
# (1680, 1680, 1680)

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':movie_point})
movie.head()
# Out:
#         date         name point
# 0 2018-07-01           당갈  9.52
# 1 2018-07-01         허스토리  9.35
# 2 2018-07-01  지금, 만나러 갑니다  9.34
# 3 2018-07-01      인크레더블 2  9.27
# 4 2018-07-01         1987  9.25

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1680 entries, 0 to 1679
# Data columns (total 3 columns):
# date     1680 non-null datetime64[ns]
# name     1680 non-null object
# point    1680 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 39.5+ KB

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1680 entries, 0 to 1679
# Data columns (total 3 columns):
# date     1680 non-null datetime64[ns]
# name     1680 non-null object
# point    1680 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 39.5+ KB

# %%
movie.to_csv("../data/04_naver_movie_raw_data.csv", sep=",", encoding="utf-8")

# %%
import numpy as np
import pandas as pd

movie = pd.read_csv("../data/04_naver_movie_raw_data.csv", index_col=0)
movie.head()
# Out:
#          date         name  point
# 0  2018-07-01           당갈   9.52
# 1  2018-07-01         허스토리   9.35
# 2  2018-07-01  지금, 만나러 갑니다   9.34
# 3  2018-07-01      인크레더블 2   9.27
# 4  2018-07-01         1987   9.25

# %%
movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_unique.head()
# Out:
#               point
# name
# 1987         323.75
# 걸어도 걸어도      302.40
# 고양이를 빌려드립니다  282.80
# 곤지암          226.45
# 공작           240.45

# %%
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best.head(10)
# Out:
#                     point
# name
# 당갈                 333.20
# 허스토리               327.25
# 지금, 만나러 갑니다        326.90
# 인크레더블 2            324.45
# 1987               323.75
# 극장판 헬로카봇 : 백악기 시대  323.40
# 명탐정 코난 : 제로의 집행인   323.05
# 어느 가족              322.70
# 러빙 빈센트             321.65
# 내 사랑               320.95

# %%
movie.query('name == ["소공녀"]')
# Out:
#             date name  point
# 16    2018-07-01  소공녀   8.88
# 64    2018-07-02  소공녀   8.88
# 112   2018-07-03  소공녀   8.88
# 160   2018-07-04  소공녀   8.88
# 208   2018-07-05  소공녀   8.88
# 256   2018-07-06  소공녀   8.88
# 304   2018-07-07  소공녀   8.88
# 352   2018-07-08  소공녀   8.88
# 400   2018-07-09  소공녀   8.88
# 448   2018-07-10  소공녀   8.88
# 496   2018-07-11  소공녀   8.88
# 544   2018-07-12  소공녀   8.88
# 592   2018-07-13  소공녀   8.88
# 640   2018-07-14  소공녀   8.88
# 688   2018-07-15  소공녀   8.88
# 736   2018-07-16  소공녀   8.88
# 784   2018-07-17  소공녀   8.88
# 832   2018-07-18  소공녀   8.88
# 880   2018-07-19  소공녀   8.88
# 928   2018-07-20  소공녀   8.88
# 976   2018-07-21  소공녀   8.88
# 1024  2018-07-22  소공녀   8.88
# 1072  2018-07-23  소공녀   8.88
# 1120  2018-07-24  소공녀   8.88
# 1168  2018-07-25  소공녀   8.88
# 1216  2018-07-26  소공녀   8.88
# 1264  2018-07-27  소공녀   8.88
# 1312  2018-07-28  소공녀   8.88
# 1360  2018-07-29  소공녀   8.88
# 1408  2018-07-30  소공녀   8.88
# 1456  2018-07-31  소공녀   8.88
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(movie.query('name == ["소공녀"]')['date'],
         movie.query('name == ["소공녀"]')['point'])
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
movie_best.head(10)
# Out:
#                     point
# name
# 당갈                 333.20
# 허스토리               327.25
# 지금, 만나러 갑니다        326.90
# 인크레더블 2            324.45
# 1987               323.75
# 극장판 헬로카봇 : 백악기 시대  323.40
# 명탐정 코난 : 제로의 집행인   323.05
# 어느 가족              322.70
# 러빙 빈센트             321.65
# 내 사랑               320.95

# %%
movie_best.tail(10)
# Out:
#                   point
# name
# 세 번째 살인          272.30
# 신과함께-인과 연        270.55
# 콜 미 바이 유어 네임     264.25
# 킬링 디어            250.60
# 공작               240.45
# 메가로돈             235.55
# 조선명탐정: 흡혈괴마의 비밀  232.75
# 곤지암              226.45
# 목격자              198.10
# 인랑               135.45

# %%
movie_pivot = movie.pivot('date', 'name', 'point')
movie_pivot.head()
# Out:
# name        1987  걸어도 걸어도  고양이를 빌려드립니다   곤지암    공작  그것만이 내 세상  \
# date
# 2018-07-01  9.25     8.64         8.08  6.47  6.87       8.92
# 2018-07-02  9.25     8.64         8.08  6.47  6.87       8.92
# 2018-07-03  9.25     8.64         8.08  6.47  6.87       8.92
# 2018-07-04  9.25     8.64         8.08  6.47  6.87       8.92
# 2018-07-05  9.25     8.64         8.08  6.47  6.87       8.92
#
# name        극장판 도라에몽: 진구의 보물섬  극장판 헬로카봇 : 백악기 시대  나를 차버린 스파이  내 사랑  ...   \
# date                                                                ...
# 2018-07-01               8.78               9.24        8.38  9.17  ...
# 2018-07-02               8.78               9.24        8.38  9.17  ...
# 2018-07-03               8.78               9.24        8.38  9.17  ...
# 2018-07-04               8.78               9.24        8.38  9.17  ...
# 2018-07-05               8.78               9.24        8.38  9.17  ...
#
# name        인크레더블 2  조선명탐정: 흡혈괴마의 비밀  지금, 만나러 갑니다  카모메 식당  콜 미 바이 유어 네임  \
# ...

# %%
movie_pivot.to_excel("../data/04_movie_pivot.xlsx")

# %%
movie_pivot.columns
# Out:
# Index(['1987', '걸어도 걸어도', '고양이를 빌려드립니다', '곤지암', '공작', '그것만이 내 세상',
#        '극장판 도라에몽: 진구의 보물섬', '극장판 헬로카봇 : 백악기 시대', '나를 차버린 스파이', '내 사랑',
#        '너의 결혼식', '노인을 위한 나라는 없다', '당갈', '러빙 빈센트', '맘마미아!2', '메가로돈',
#        '명탐정 코난 : 제로의 집행인', '목격자', '몬스터 호텔 3', '미션 임파서블: 폴아웃', '바닷마을 다이어리',
#        '바르다가 사랑한 얼굴들', '부르고뉴, 와인에서 찾은 인생', '비포 선라이즈', '세 번째 살인', '소공녀',
#        '시카리오: 데이 오브 솔다도', '신과함께-인과 연', '신비아파트: 금빛 도깨비와 비밀의 동굴',
#        '신은 죽지 않았다 3: 어둠 속의 빛', '아비정전', '아이 엠 러브', '안경', '앤트맨과 와스프', '어느 가족',
#        '어벤져스: 인피니티 워', '이별의 아침에 약속의 꽃을 장식하자', '인랑', '인크레더블 2',
#        '조선명탐정: 흡혈괴마의 비밀', '지금, 만나러 갑니다', '카모메 식당', '콜 미 바이 유어 네임', '킬링 디어',
#        '탐정: 리턴즈', '파리로 가는 길', '한여름의 판타지아', '허스토리'],
#       dtype='object', name='name')

# %%
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False
import seaborn as sns

f_path = "/Library/Fonts/AppleGothic.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
target_col = ['1987', '노인을 위한 나라는 없다', '신과함께-인과 연', '당갈', '인랑']
plt.figure(figsize=(12,8))
plt.plot(movie_pivot[target_col])
plt.legend(target_col, loc='best')
plt.tick_params(bottom=False, labelbottom=False)
plt.show()
