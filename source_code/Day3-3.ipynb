# %%
import urllib.request
client_id = "x8q4zmKNuZPO1zDzeaO9"
client_secret = "fIAlOkUaiG"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

# %%
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Wed, 29 Aug 2018 14:58:06 +0900",
# "total": 79266,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "&quot;진정한 <b>파이썬</b> 고급 개발자가 되기 위한 능력을... ",
# "link": "http://blog.naver.com/fastcampus?Redirect=Log&amp;logNo=221313946171",
# "description": "<b>파이썬</b>은 백엔드 개발에서부터 데이터 분석에 이르기까지 광범위하게 사용되고 있는 간편하지만 강력한 언어입니다. <b>파이썬</b> 코어를 이해하면 더 깊이 있는 개발이 가능해지고 활용 범위도 확장됩니다. 여기... ",
# "bloggername": "패스트캠퍼스 : FAST CAMPUS",
# "bloggerlink": "http://blog.naver.com/fastcampus",
# "postdate": "20180706"
#
# },
# {
# "title": "<b>파이썬</b>(python)학원 고르는 팁(tip)!",
# "link": "http://blog.naver.com/wkfkeh1?Redirect=Log&amp;logNo=221343790861",
# "description": "이 코딩이란 것, 프로그래밍이란 것을 하기위해 필수로 알아야 하는 코딩 언어들 중 <b>파이썬</b> 코딩 언어와 <b>파이썬</b> 학원에 대해 알아보겠습니다! 코딩(프로그래밍)을 하는데 있어서 대중적으로 많이 알려져... ",
# "bloggername": "무선생의 정보보안 세상",
# "bloggerlink": "http://blog.naver.com/wkfkeh1",
# "postdate": "20180822"
#
# },
# {
# "title": "<b>파이썬</b> 시작하기",
# "link": "http://blog.naver.com/3yong2ya?Redirect=Log&amp;logNo=221330118869",
# "description": "이제서야 <b>파이썬</b>을 접해본다. 이 글은 30분동안 몇가지 예제 돌려보고 The Python Standard Library 라는 문서를 보면서 쓰는 글이다. https://docs.python.org/3/library/index.html <b>파이썬</b> 2와 3는... ",
# "bloggername": "소비자가 되지 말고, 생산자가 되자!",
# "bloggerlink": "http://blog.naver.com/3yong2ya",
# "postdate": "20180731"
#
# },
# {
# "title": "<b>파이썬</b>의 시작 변수, 주석달기, 자료형 설명",
# "link": "http://blog.naver.com/so15284?Redirect=Log&amp;logNo=221347225551",
# "description": "안녕하세요 <b>파이썬</b> 시작의 두번째 시간 변수랑 주석 달기, 자료형 설명을 해드리겠습니다. 솔직히... 때문입니다.) <b>파이썬</b>에서는 주석은 #으로 주석처리를 합니다! 참고하시길 바랍니다. 마지막으로 변수형... ",
# "bloggername": "곧",
# "bloggerlink": "http://blog.naver.com/so15284",
# "postdate": "20180827"
#
# },
# {
# "title": "[슬기로운 코딩생활] with <b>파이썬</b>-으랏차차 기초편",
# "link": "http://blog.naver.com/willout?Redirect=Log&amp;logNo=221300282869",
# "description": "슬기로운 코딩 생활 with <b>파이썬</b> 으랏차차 기초편 저자 김정욱, 김준석 출판 루비페이퍼 발매 2018.05.15.... 수업으로 <b>파이썬</b>을 하더라구요. 지금 공대로 가려는 고등학생들도 대학입학을 코앞에 앞두고... ",
# "bloggername": "구름한잔",
# "bloggerlink": "http://blog.naver.com/willout",
# "postdate": "20180616"
#
# },
# {
# "title": "<b>파이썬</b>, 아나콘다 설치하기",
# "link": "http://blog.naver.com/kiddwannabe?Redirect=Log&amp;logNo=221154599192",
# "description": "<b>파이썬</b> 및 아나콘다 / 쥬피터노트북 설치에 대해 알아보겠습니다. 1. <b>파이썬</b>? - <b>파이썬</b>의 장점 : 쉽다. 무료. 사람들이 많이 쓴다. ① (다른 언어에 비해) 코딩하는 것이 참 쉽습니다. 어떻게 보면 융통성?... ",
# "bloggername": "데이터공방 - 파이썬/크롤링/머신러닝/시각화",
# "bloggerlink": "http://blog.naver.com/kiddwannabe",
# "postdate": "20171204"
#
# },
# {
# "title": "오늘의 일상기획, 문과생이 <b>파이썬</b>을 배운다는 것은.",
# "link": "http://blog.naver.com/herjayoung?Redirect=Log&amp;logNo=221320214060",
# "description": "<b>파이썬</b>! 내가 한번 정복해보리라! 요즘 <b>파이썬</b>을 배우고 있다. 며칠 전 트렌토리를 들으면서 내가 생각이 들었던 몇 가지가 있었다. 앞으로 코딩과 영상, 디자인을 잘 한다면 경쟁력이 있을 것 같다는 생각이... ",
# "bloggername": "성 장 하 는 일 상 기 획 자",
# "bloggerlink": "http://blog.naver.com/herjayoung",
# "postdate": "20180716"
#
# },
# {
# "title": "[도서리뷰] Hello Coding 한입에 쏙 <b>파이썬</b>, 부제 : 진짜로... ",
# "link": "http://blog.naver.com/lsszz210?Redirect=Log&amp;logNo=221317270276",
# "description": "Hello Coding 한입에 쏙 <b>파이썬</b> 저자 김왼손, 김태간 출판 한빛미디어 발매 2018.06.20. Hello Coding 한입에 쏙 <b>파이썬</b>. 부제 : 진짜로 한입에 쏙 담기는 코딩일까? 프로그래밍이 처음이신가요? 프로그래밍이... ",
# "bloggername": "IT Mania Library (프로그래밍, IT 정보)",
# "bloggerlink": "http://blog.naver.com/lsszz210",
# "postdate": "20180711"
#
# },
# {
# "title": "<b>파이썬</b>학원 빅데이터전문가 기초 교육",
# "link": "http://blog.naver.com/hjchoi1500?Redirect=Log&amp;logNo=221320186158",
# "description": "<b>파이썬</b>학원 빅데이터전문가 기초 교육 개발 축에서 메인은 자바가, 서브 프로세스는 <b>파이썬</b>이 잡는 일반적인 형태에서 머신러닝이 대두하며 이제는 각축을 잡는 메인이 되어버린 <b>파이썬</b>입니다... ",
# "bloggername": "소소한 새벽의 하루",
# "bloggerlink": "http://blog.naver.com/hjchoi1500",
# "postdate": "20180716"
#
# },
# {
# "title": "<b>파이썬</b>독학 어렵지 않습니다",
# "link": "http://blog.naver.com/skyktc?Redirect=Log&amp;logNo=221302923803",
# "description": "오늘은 여러분들께<b>파이썬</b>독학 방법을 알려드리려고 합니다괜찮은 강의와 수강후기도 가져왔으니까포스팅에 집중해주시면 감사하겠습니다! <b>파이썬</b>은 프로그래밍에 처음 입문하는 분들이많이 배우는... ",
# "bloggername": "스마트동스쿨 공식블로그",
# "bloggerlink": "http://blog.naver.com/skyktc",
# "postdate": "20180620"
#
# }
# ]
# }

# %%
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/movie?query=" + encText # json 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Wed, 29 Aug 2018 15:11:50 +0900",
# "total": 1,
# "start": 1,
# "display": 1,
# "items": [
# {
# "title": "<b>파이썬</b> 앤 가드",
# "link": "https://movie.naver.com/movie/bi/mi/basic.nhn?code=152070",
# "image": "https://ssl.pstatic.net/imgmovie/mdi/mit110/1520/152070_P01_145336.jpg",
# "subtitle": "PYTHON AND GUARD",
# "pubDate": "2015",
# "director": "안톤 디아코프|",
# "actor": "",
# "userRating": "0.00"
#
# }
# ]
# }

# %%
import urllib.request

encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/book?query=" + encText # json 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Wed, 29 Aug 2018 14:59:32 +0900",
# "total": 673,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b>으로 데이터 주무르기 (독특한 예제를 통해 배우는 데이터 분석 입문)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12898027",
# "image": "https://bookthumb-phinf.pstatic.net/cover/128/980/12898027.jpg?type=m1&udate=20180316",
# "author": "민형기",
# "price": "27500",
# "discount": "24750",
# "publisher": "비제이퍼블릭",
# "pubdate": "20171229",
# "isbn": "1186697474 9791186697474",
# "description": "있을 <b>파이썬</b> 기초 문법책과 같은 내용이 아닌, 데이터 분석이라는 특별한 분야에서 초보를 위해 처음부터 끝까지 <b>파이썬</b>으로 진행되는 과정을 다룹니다. 서울시 범죄 현황 분석, 셀프 주유소 가격 정보 분석, 19대 대선 결과 분석 등 흥미 있는 목표를 이루기 위해서 <b>파이썬</b>의 기초를 익히고, 데이터를 다루고... "
#
# },
# {
# "title": "<b>파이썬</b>과 케라스를 이용한 딥러닝/강화학습 주식투자 (퀀트 투자, 알고리즘 트레이딩을 위한 최첨단 해법 입문)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13608435",
# "image": "https://bookthumb-phinf.pstatic.net/cover/136/084/13608435.jpg?type=m1&udate=20180619",
# "author": "김문권",
# "price": "25000",
# "discount": "22500",
# "publisher": "위키북스",
# "pubdate": "20180529",
# "isbn": "1158391064 9791158391065",
# "description": "이 책은 <b>파이썬</b>을 이용한 강화학습 기반의 주식투자 시뮬레이션 프로그램을 개발하는 방법을 설명합니다. 이를 위해 이론과 코드 수준에서 상세한 설명을 덧붙였습니다. 이 책을 통해 딥러닝과 강화학습을 이해하고 이를 주식투자를 비롯한 다양한 도메인에서 활용할 수 있을 것입니다."
#
# },
# {
# "title": "Do it! 점프 투 <b>파이썬</b> (이미 50만 명이 '점프 투 <b>파이썬</b>'으로 시작했다!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=10290989",
# "image": "https://bookthumb-phinf.pstatic.net/cover/102/909/10290989.jpg?type=m1&udate=20180306",
# "author": "박응용",
# "price": "18800",
# "discount": "16920",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20160303",
# "isbn": "8997390910 9788997390915",
# "description": "스스로 <b>파이썬</b> 프로그램을 만들 수 있는 실력을 키워보자!《DO IT! 점프 투 <b>파이썬</b>》은 지난 10년간 온라인 독자들의 질문 댓글에 답변하며 쌓아온... 책은 <b>파이썬</b>의 문법들을 실생활에서 쉽게 접할 수 있는 일들을 사례로 들어 설명하는 저자의 탁월함이 돋보인다. 더불어 최신 <b>파이썬</b> 3버전을 기준으로 내용을... "
#
# },
# {
# "title": "<b>파이썬</b> 라이브러리를 활용한 머신러닝 (사이킷런 핵심 개발자가 쓴 머신러닝과 데이터 과학 실무서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12174889",
# "image": "https://bookthumb-phinf.pstatic.net/cover/121/748/12174889.jpg?type=m1&udate=20171122",
# "author": "안드레아스 뮐러|세라 가이도",
# "price": "30000",
# "discount": "27000",
# "publisher": "한빛미디어",
# "pubdate": "20170701",
# "isbn": "8968483396 9788968483394",
# "description": "사이킷런 핵심 개발자에게 배우는 머신러닝 이론과 구현현업에서 머신러닝을 연구하고 인공지능 서비스를 개발하기 위해 꼭 학위를 받을 필요는 없다. 사이킷런(SCIKIT-LEARN)과 같은 훌륭한 머신러닝 라이브러리가 복잡하고 난해한 작업을 직관적인 인터페이스로 감싸주는 덕분. 이 책에서는 사이킷런의... "
#
# },
# {
# "title": "모두의 <b>파이썬</b> (20일 만에 배우는 프로그래밍 기초)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=10541921",
# "image": "https://bookthumb-phinf.pstatic.net/cover/105/419/10541921.jpg?type=m1&udate=20171019",
# "author": "이승찬",
# "price": "12000",
# "discount": "10800",
# "publisher": "길벗",
# "pubdate": "20160509",
# "isbn": "1186978899 9791186978894",
# "description": "<b>파이썬</b>이 무엇인지 몰라도 상관 없다. 《모두의 <b>파이썬</b>》은 어려운 개념과 복잡한 이론 설명은 최대한 줄이고, 초보자가 프로그래밍을 쉽게 배울 수... 어느새 <b>파이썬</b> 프로그램으로 멋진 그림을 그리고, 계산을 하고, 간단한 게임을 만들고, 수학 문제를 푸는 자신을 발견하게 될 것이다. 《모두의 <b>파이썬</b>》으로... "
#
# },
# {
# "title": "<b>파이썬</b> GUI 프로그래밍 쿡북 (<b>파이썬</b> 3로 쉽고 빠르게 GUI 개발하기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13541856",
# "image": "https://bookthumb-phinf.pstatic.net/cover/135/418/13541856.jpg?type=m1&udate=20180619",
# "author": "부르크하르트 메이어",
# "price": "35000",
# "discount": "31500",
# "publisher": "에이콘출판",
# "pubdate": "20180426",
# "isbn": "1161751475 9791161751474",
# "description": "<b>파이썬</b> 3를 사용해 GUI 프로그래밍 방법을 단계별로 설명하는 유용한 책이다. 앞의 레시피를 개선해... 만드는 <b>파이썬</b>의 심플함과 강력함에 놀라운 즐거움을 느끼게 되리라 생각한다.\n\n★ 이 책에서... <b>파이썬</b> 프로그래밍 언어를 사용해 아름답고, 기능적이고, 강력한 GUI를 만들면서 이룰 수 있는 것에... "
#
# },
# {
# "title": "모두의 알고리즘 with <b>파이썬</b> (컴퓨팅 사고를 위한 기초 알고리즘)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12057147",
# "image": "https://bookthumb-phinf.pstatic.net/cover/120/571/12057147.jpg?type=m1&udate=20171019",
# "author": "이승찬",
# "price": "16000",
# "discount": "14400",
# "publisher": "길벗",
# "pubdate": "20170518",
# "isbn": "1160501726 9791160501728",
# "description": "《모두의 알고리즘 WITH <b>파이썬</b>》은 중요하지만 어려운 주제인 알고리즘을 초보자와 비전공자가 배울 수 있게 최대한 전문 용어와 복잡한 수학을 사용하지 않고 설명한다. 또한, 간단한 문제를 풀면서 기초 알고리즘을 설명하기 때문에 쉽게 이해할 수 있다. 그동안 알고리즘을 배우고 싶었지만, 어려워서... "
#
# },
# {
# "title": "<b>파이썬</b>과 케라스로 배우는 강화학습 (내 손으로 직접 구현하는 게임 인공지능)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12299291",
# "image": "https://bookthumb-phinf.pstatic.net/cover/122/992/12299291.jpg?type=m1&udate=20171122",
# "author": "이웅원|양혁렬|김건우|이영무|이의령",
# "price": "27000",
# "discount": "24300",
# "publisher": "위키북스",
# "pubdate": "20170731",
# "isbn": "1158390726 9791158390723",
# "description": "“강화학습을 쉽게 이해하고 코드로 구현하기”강화학습의 기초부터 최근 알고리즘까지 친절하게 설명한다! ‘알파고’로부터 받은 신선한 충격으로 많은 사람들이 강화학습에 관심을 가지기 시작했다. 하지만 처음 강화학습을 공부하는 분들을 위한 쉬운 자료나 강의를 찾아보기 어려웠다. 외국 강의를 통해... "
#
# },
# {
# "title": "<b>파이썬</b>으로 배우는 알고리즘 트레이딩 (내 손으로 만드는 자동 주식 거래 시스템)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12035489",
# "image": "https://bookthumb-phinf.pstatic.net/cover/120/354/12035489.jpg?type=m1&udate=20180822",
# "author": "조대표",
# "price": "40000",
# "discount": "36000",
# "publisher": "위키북스",
# "pubdate": "20170517",
# "isbn": "1158390637 9791158390631",
# "description": "『<b>파이썬</b>으로 배우는 알고리즘 트레이딩』은 <b>파이썬</b>이라는 프로그래밍 언어를 이용한 알고리즘 트레이딩을 다룬 책이다. 프로그래밍을 전혀 모르는 비전공자나 HTS(Home Trading System)로 주식 투자 정도만 할 수 있는 일반인도 빠르게 <b>파이썬</b>과 알고리즘 트레이딩을 배울 수 있는... "
#
# },
# {
# "title": "<b>파이썬</b> 데이터 분석 입문 (엑셀 및 CSV 파일 처리부터 데이터베이스, 시각화, 통계분석, 자동화까지)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12657786",
# "image": "https://bookthumb-phinf.pstatic.net/cover/126/577/12657786.jpg?type=m1&udate=20180426",
# "author": "클린턴 브라운리",
# "price": "27000",
# "discount": "24300",
# "publisher": "한빛미디어",
# "pubdate": "20171025",
# "isbn": "1162240148 9791162240144",
# "description": "엑셀의 한계를 넘어 <b>파이썬</b>을 이용한 데이터 분석으로\n\n엑셀은 쉽고 직관적이지만 수백 개의 파일을 다루기는 무리다. <b>파이썬</b>을 이용하면 엑셀의 한계를 넘어 다양한 형식의 데이터를 가공하고 수많은 파일을 분석할 수 있다. 이 책은 일반인을 위한 <b>파이썬</b> 기초부터 CSV, 엑셀, 데이터베이스의 데이터를 분석하는... "
#
# }
# ]
# }

# %%
encText = urllib.parse.quote("몰스킨")
url = "https://openapi.naver.com/v1/search/shop.json?query=" + encText

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Wed, 29 Aug 2018 15:12:28 +0900",
# "total": 22464,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>몰스킨</b> 클래식 룰드 줄지",
# "link": "http://search.shopping.naver.com/gate.nhn?id=7398991731",
# "image": "https://shopping-phinf.pstatic.net/main_7398991/7398991731.20180112135400.jpg",
# "lprice": "15690",
# "hprice": "40690",
# "mallName": "네이버",
# "productId": "7398991731",
# "productType": "1"
#
# },
# {
# "title": "KM <b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 노트북 9788",
# "link": "http://search.shopping.naver.com/gate.nhn?id=13372539964",
# "image": "https://shopping-phinf.pstatic.net/main_1337253/13372539964.1.jpg",
# "lprice": "19400",
# "hprice": "0",
# "mallName": "N펀키보이",
# "productId": "13372539964",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 까이에 엑스라지 다이어리",
# "link": "http://search.shopping.naver.com/gate.nhn?id=10010203158",
# "image": "https://shopping-phinf.pstatic.net/main_1001020/10010203158.20160704125951.jpg",
# "lprice": "8700",
# "hprice": "34100",
# "mallName": "네이버",
# "productId": "10010203158",
# "productType": "1"
#
# },
# {
# "title": "<b>몰스킨</b> 2017 위클리 18개월 그린 하드 다이어리",
# "link": "http://search.shopping.naver.com/gate.nhn?id=10010117049",
# "image": "https://shopping-phinf.pstatic.net/main_1001011/10010117049.20160704125551.jpg",
# "lprice": "20000",
# "hprice": "228500",
# "mallName": "네이버",
# "productId": "10010117049",
# "productType": "1"
#
# },
# {
# "title": "<b>몰스킨</b> 와인 저널",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14462045410",
# "image": "https://shopping-phinf.pstatic.net/main_1446204/14462045410.jpg",
# "lprice": "28880",
# "hprice": "0",
# "mallName": "CJmall",
# "productId": "14462045410",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 2018 스누피 다이어리",
# "link": "http://search.shopping.naver.com/gate.nhn?id=12606204666",
# "image": "https://shopping-phinf.pstatic.net/main_1260620/12606204666.1.jpg",
# "lprice": "12000",
# "hprice": "0",
# "mallName": "홀세일스토어",
# "productId": "12606204666",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162",
# "link": "http://search.shopping.naver.com/gate.nhn?id=15000292575",
# "image": "https://shopping-phinf.pstatic.net/main_1500029/15000292575.jpg",
# "lprice": "19000",
# "hprice": "0",
# "mallName": "바이탑",
# "productId": "15000292575",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 피너츠 데일리 2018 코랄오렌지 라지 55532",
# "link": "http://search.shopping.naver.com/gate.nhn?id=13539545478",
# "image": "https://shopping-phinf.pstatic.net/main_1353954/13539545478.jpg",
# "lprice": "8990",
# "hprice": "0",
# "mallName": "인터파크",
# "productId": "13539545478",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 피너츠 데일리 2018 코랄오렌지 라지 55532",
# "link": "http://search.shopping.naver.com/gate.nhn?id=80566520418",
# "image": "https://shopping-phinf.pstatic.net/main_8056652/80566520418.1.jpg",
# "lprice": "9900",
# "hprice": "0",
# "mallName": "유에스몰코리아",
# "productId": "80566520418",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 2018 / 위클리 / 블랙 소프트 / 라지L",
# "link": "http://search.shopping.naver.com/gate.nhn?id=15079581331",
# "image": "https://shopping-phinf.pstatic.net/main_1507958/15079581331.jpg",
# "lprice": "14000",
# "hprice": "0",
# "mallName": "펜스토어",
# "productId": "15079581331",
# "productType": "2"
#
# }
# ]
# }

# %%
import datetime

def get_request_url(API_url):
    client_id = "x8q4zmKNuZPO1zDzeaO9"
    client_secret = "fIAlOkUaiG"

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    
    response = urllib.request.urlopen(request)
    
    if(rescode==200):
        print("[%s] Url Request Success" % datetime.datetime.now())
        return (response.read().decode('utf-8'))
    else:
        print("[%s] Error -------------" % datetime.datetime.now())
        return None

# %%
encText = urllib.parse.quote("몰스킨")
API_url = "https://openapi.naver.com/v1/search/shop.json?query=" + encText
print(get_request_url(API_url))
# Out:
# [2018-08-29 15:12:37.312947] Url Request Success
# {
# "lastBuildDate": "Wed, 29 Aug 2018 15:12:37 +0900",
# "total": 22464,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>몰스킨</b> 클래식 룰드 줄지",
# "link": "http://search.shopping.naver.com/gate.nhn?id=7398991731",
# "image": "https://shopping-phinf.pstatic.net/main_7398991/7398991731.20180112135400.jpg",
# "lprice": "15690",
# "hprice": "40690",
# "mallName": "네이버",
# "productId": "7398991731",
# "productType": "1"
#
# },
# {
# "title": "KM <b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 노트북 9788",
# "link": "http://search.shopping.naver.com/gate.nhn?id=13372539964",
# "image": "https://shopping-phinf.pstatic.net/main_1337253/13372539964.1.jpg",
# "lprice": "19400",
# "hprice": "0",
# "mallName": "N펀키보이",
# "productId": "13372539964",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 까이에 엑스라지 다이어리",
# "link": "http://search.shopping.naver.com/gate.nhn?id=10010203158",
# "image": "https://shopping-phinf.pstatic.net/main_1001020/10010203158.20160704125951.jpg",
# "lprice": "8700",
# "hprice": "34100",
# "mallName": "네이버",
# "productId": "10010203158",
# "productType": "1"
#
# },
# {
# "title": "<b>몰스킨</b> 2017 위클리 18개월 그린 하드 다이어리",
# "link": "http://search.shopping.naver.com/gate.nhn?id=10010117049",
# "image": "https://shopping-phinf.pstatic.net/main_1001011/10010117049.20160704125551.jpg",
# "lprice": "20000",
# "hprice": "228500",
# "mallName": "네이버",
# "productId": "10010117049",
# "productType": "1"
#
# },
# {
# "title": "<b>몰스킨</b> 와인 저널",
# "link": "http://search.shopping.naver.com/gate.nhn?id=14462045410",
# "image": "https://shopping-phinf.pstatic.net/main_1446204/14462045410.jpg",
# "lprice": "28880",
# "hprice": "0",
# "mallName": "CJmall",
# "productId": "14462045410",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 2018 스누피 다이어리",
# "link": "http://search.shopping.naver.com/gate.nhn?id=12606204666",
# "image": "https://shopping-phinf.pstatic.net/main_1260620/12606204666.1.jpg",
# "lprice": "12000",
# "hprice": "0",
# "mallName": "홀세일스토어",
# "productId": "12606204666",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162",
# "link": "http://search.shopping.naver.com/gate.nhn?id=15000292575",
# "image": "https://shopping-phinf.pstatic.net/main_1500029/15000292575.jpg",
# "lprice": "19000",
# "hprice": "0",
# "mallName": "바이탑",
# "productId": "15000292575",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 피너츠 데일리 2018 코랄오렌지 라지 55532",
# "link": "http://search.shopping.naver.com/gate.nhn?id=13539545478",
# "image": "https://shopping-phinf.pstatic.net/main_1353954/13539545478.jpg",
# "lprice": "8990",
# "hprice": "0",
# "mallName": "인터파크",
# "productId": "13539545478",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 피너츠 데일리 2018 코랄오렌지 라지 55532",
# "link": "http://search.shopping.naver.com/gate.nhn?id=80566520418",
# "image": "https://shopping-phinf.pstatic.net/main_8056652/80566520418.1.jpg",
# "lprice": "9900",
# "hprice": "0",
# "mallName": "유에스몰코리아",
# "productId": "80566520418",
# "productType": "2"
#
# },
# {
# "title": "<b>몰스킨</b> 2018 / 위클리 / 블랙 소프트 / 라지L",
# "link": "http://search.shopping.naver.com/gate.nhn?id=15079581331",
# "image": "https://shopping-phinf.pstatic.net/main_1507958/15079581331.jpg",
# "lprice": "14000",
# "hprice": "0",
# "mallName": "펜스토어",
# "productId": "15079581331",
# "productType": "2"
#
# }
# ]
# }

# %%
def get_search_result(api_node, search_text, start_num, disp_num):
    
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    
    url = base + node + param_query + param_start + param_disp
    
    print(url)

# %%
get_search_result('shop', 'TEST', 10, 3)
# Out:
# https://openapi.naver.com/v1/search/shop.json?query=TEST&start=10&display=3

# %%
import json
def get_search_result(api_node, search_text, start_num, disp_num):
    
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)
    
    url = base + node + param_query + param_start + param_disp
    
    getting_data = get_request_url(url)
    
    if(getting_data == None):
        return None
    else:
        return json.loads(getting_data)

# %%
search_result = get_search_result('shop', '몰스킨', 1, 2)
# Out:
# [2018-08-29 15:14:51.517240] Url Request Success

# %%
search_result
# Out:
# {'lastBuildDate': 'Wed, 29 Aug 2018 15:14:51 +0900',
#  'total': 22464,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '<b>몰스킨</b> 클래식 룰드 줄지',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=7398991731',
#    'image': 'https://shopping-phinf.pstatic.net/main_7398991/7398991731.20180112135400.jpg',
#    'lprice': '15690',
#    'hprice': '40690',
#    'mallName': '네이버',
#    'productId': '7398991731',
#    'productType': '1'},
#   {'title': 'KM <b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 노트북 9788',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=13372539964',
#    'image': 'https://shopping-phinf.pstatic.net/main_1337253/13372539964.1.jpg',
#    'lprice': '19400',
#    'hprice': '0',
#    'mallName': 'N펀키보이',
#    'productId': '13372539964',
#    'productType': '2'},
#   {'title': '<b>몰스킨</b> 까이에 엑스라지 다이어리',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=10010203158',
#    'image': 'https://shopping-phinf.pstatic.net/main_1001020/10010203158.20160704125951.jpg',
#    'lprice': '8700',
#    'hprice': '34100',
#    'mallName': '네이버',
#    'productId': '10010203158',
#    'productType': '1'},
#   {'title': '<b>몰스킨</b> 2017 위클리 18개월 그린 하드 다이어리',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=10010117049',
#    'image': 'https://shopping-phinf.pstatic.net/main_1001011/10010117049.20160704125551.jpg',
#    'lprice': '20000',
#    'hprice': '228500',
#    'mallName': '네이버',
#    'productId': '10010117049',
#    'productType': '1'},
#   {'title': '<b>몰스킨</b> 와인 저널',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=14462045410',
#    'image': 'https://shopping-phinf.pstatic.net/main_1446204/14462045410.jpg',
#    'lprice': '28880',
#    'hprice': '0',
#    'mallName': 'CJmall',
#    'productId': '14462045410',
#    'productType': '2'},
#   {'title': '<b>몰스킨</b> 2018 스누피 다이어리',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=12606204666',
#    'image': 'https://shopping-phinf.pstatic.net/main_1260620/12606204666.1.jpg',
#    'lprice': '12000',
#    'hprice': '0',
#    'mallName': '홀세일스토어',
#    'productId': '12606204666',
#    'productType': '2'},
#   {'title': '<b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=15000292575',
#    'image': 'https://shopping-phinf.pstatic.net/main_1500029/15000292575.jpg',
#    'lprice': '19000',
#    'hprice': '0',
#    'mallName': '바이탑',
#    'productId': '15000292575',
#    'productType': '2'},
#   {'title': '<b>몰스킨</b> 피너츠 데일리 2018 코랄오렌지 라지 55532',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=13539545478',
#    'image': 'https://shopping-phinf.pstatic.net/main_1353954/13539545478.jpg',
#    'lprice': '8990',
#    'hprice': '0',
#    'mallName': '인터파크',
#    'productId': '13539545478',
#    'productType': '2'},
#   {'title': '<b>몰스킨</b> 피너츠 데일리 2018 코랄오렌지 라지 55532',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=80566520418',
#    'image': 'https://shopping-phinf.pstatic.net/main_8056652/80566520418.1.jpg',
#    'lprice': '9900',
#    'hprice': '0',
#    'mallName': '유에스몰코리아',
#    'productId': '80566520418',
#    'productType': '2'},
#   {'title': '<b>몰스킨</b> 2018 / 위클리 / 블랙 소프트 / 라지L',
#    'link': 'http://search.shopping.naver.com/gate.nhn?id=15079581331',
#    'image': 'https://shopping-phinf.pstatic.net/main_1507958/15079581331.jpg',
#    'lprice': '14000',
#    'hprice': '0',
#    'mallName': '펜스토어',
#    'productId': '15079581331',
#    'productType': '2'}]}

# %%
search_result['items']
# Out:
# [{'title': '<b>몰스킨</b> 클래식 룰드 줄지',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=7398991731',
#   'image': 'https://shopping-phinf.pstatic.net/main_7398991/7398991731.20180112135400.jpg',
#   'lprice': '15690',
#   'hprice': '40690',
#   'mallName': '네이버',
#   'productId': '7398991731',
#   'productType': '1'},
#  {'title': 'KM <b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 노트북 9788',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=13372539964',
#   'image': 'https://shopping-phinf.pstatic.net/main_1337253/13372539964.1.jpg',
#   'lprice': '19400',
#   'hprice': '0',
#   'mallName': 'N펀키보이',
#   'productId': '13372539964',
#   'productType': '2'},
#  {'title': '<b>몰스킨</b> 까이에 엑스라지 다이어리',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=10010203158',
#   'image': 'https://shopping-phinf.pstatic.net/main_1001020/10010203158.20160704125951.jpg',
#   'lprice': '8700',
#   'hprice': '34100',
#   'mallName': '네이버',
#   'productId': '10010203158',
#   'productType': '1'},
#  {'title': '<b>몰스킨</b> 2017 위클리 18개월 그린 하드 다이어리',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=10010117049',
#   'image': 'https://shopping-phinf.pstatic.net/main_1001011/10010117049.20160704125551.jpg',
#   'lprice': '20000',
#   'hprice': '228500',
#   'mallName': '네이버',
#   'productId': '10010117049',
#   'productType': '1'},
#  {'title': '<b>몰스킨</b> 와인 저널',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=14462045410',
#   'image': 'https://shopping-phinf.pstatic.net/main_1446204/14462045410.jpg',
#   'lprice': '28880',
#   'hprice': '0',
#   'mallName': 'CJmall',
#   'productId': '14462045410',
#   'productType': '2'},
#  {'title': '<b>몰스킨</b> 2018 스누피 다이어리',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=12606204666',
#   'image': 'https://shopping-phinf.pstatic.net/main_1260620/12606204666.1.jpg',
#   'lprice': '12000',
#   'hprice': '0',
#   'mallName': '홀세일스토어',
#   'productId': '12606204666',
#   'productType': '2'},
#  {'title': '<b>몰스킨</b> 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=15000292575',
#   'image': 'https://shopping-phinf.pstatic.net/main_1500029/15000292575.jpg',
#   'lprice': '19000',
#   'hprice': '0',
#   'mallName': '바이탑',
#   'productId': '15000292575',
#   'productType': '2'},
#  {'title': '<b>몰스킨</b> 피너츠 데일리 2018 코랄오렌지 라지 55532',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=13539545478',
#   'image': 'https://shopping-phinf.pstatic.net/main_1353954/13539545478.jpg',
#   'lprice': '8990',
#   'hprice': '0',
#   'mallName': '인터파크',
#   'productId': '13539545478',
#   'productType': '2'},
#  {'title': '<b>몰스킨</b> 피너츠 데일리 2018 코랄오렌지 라지 55532',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=80566520418',
#   'image': 'https://shopping-phinf.pstatic.net/main_8056652/80566520418.1.jpg',
#   'lprice': '9900',
#   'hprice': '0',
#   'mallName': '유에스몰코리아',
#   'productId': '80566520418',
#   'productType': '2'},
#  {'title': '<b>몰스킨</b> 2018 / 위클리 / 블랙 소프트 / 라지L',
#   'link': 'http://search.shopping.naver.com/gate.nhn?id=15079581331',
#   'image': 'https://shopping-phinf.pstatic.net/main_1507958/15079581331.jpg',
#   'lprice': '14000',
#   'hprice': '0',
#   'mallName': '펜스토어',
#   'productId': '15079581331',
#   'productType': '2'}]

# %%
search_result['start'], search_result['total'], search_result['display']
# Out:
# (1, 22464, 10)

# %%
search_result['items'][0]['title']
# Out:
# '<b>몰스킨</b> 클래식 룰드 줄지'

# %%
search_result['items'][0]['lprice'], search_result['items'][0]['hprice']
# Out:
# ('15690', '40690')

# %%
search_result['items'][0]['title'].replace("<b>", "")
# Out:
# '몰스킨</b> 클래식 룰드 줄지'

# %%
def delete_tag(input_str):
    input_str = input_str.replace("<b>","")
    input_str = input_str.replace("</b>","")
    return input_str

# %%
import pandas as pd

def get_fields(post):
    title = []
    link = []
    lprice = []
    hprice = []
    
    for each in post:
        title.append(delete_tag(each['title']))
        link.append(each['link'])
        lprice.append(each['lprice'])
        hprice.append(each['hprice'])
        
    result_pd = pd.DataFrame({'title':title, 'lprice':lprice,
                              'hprice': hprice, 'link':link},
                             columns=['title', 'lprice', 'hprice', 'link'])
    
    return result_pd

# %%
get_fields(search_result['items'])
# Out:
#                                     title lprice  hprice  \
# 0                           몰스킨 클래식 룰드 줄지  15690   40690
# 1      KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 2                       몰스킨 까이에 엑스라지 다이어리   8700   34100
# 3            몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 4                               몰스킨 와인 저널  28880       0
# 5                       몰스킨 2018 스누피 다이어리  12000       0
# 6  몰스킨 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162  19000       0
# 7         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   8990       0
# 8         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   9900       0
# 9           몰스킨 2018 / 위클리 / 블랙 소프트 / 라지L  14000       0
#
#                                                 link
# 0  http://search.shopping.naver.com/gate.nhn?id=7...
# 1  http://search.shopping.naver.com/gate.nhn?id=1...
# 2  http://search.shopping.naver.com/gate.nhn?id=1...
# 3  http://search.shopping.naver.com/gate.nhn?id=1...
# 4  http://search.shopping.naver.com/gate.nhn?id=1...
# 5  http://search.shopping.naver.com/gate.nhn?id=1...
# 6  http://search.shopping.naver.com/gate.nhn?id=1...
# 7  http://search.shopping.naver.com/gate.nhn?id=1...
# 8  http://search.shopping.naver.com/gate.nhn?id=8...
# 9  http://search.shopping.naver.com/gate.nhn?id=1...

# %%
search_result = get_search_result('shop', '몰스킨', 1, 2)
tmp1 = get_fields(search_result['items'])
tmp1
# Out:
# [2018-08-29 15:37:02.617773] Url Request Success
#                                     title lprice  hprice  \
# 0                           몰스킨 클래식 룰드 줄지  15690   40690
# 1      KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 2                       몰스킨 까이에 엑스라지 다이어리   8700   34100
# 3            몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 4                               몰스킨 와인 저널  28880       0
# 5                       몰스킨 2018 스누피 다이어리  12000       0
# 6  몰스킨 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162  19000       0
# 7         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   8990       0
# 8         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   9900       0
# 9           몰스킨 2018 / 위클리 / 블랙 소프트 / 라지L  14000       0
#
#                                                 link
# 0  http://search.shopping.naver.com/gate.nhn?id=7...
# 1  http://search.shopping.naver.com/gate.nhn?id=1...
# 2  http://search.shopping.naver.com/gate.nhn?id=1...
# 3  http://search.shopping.naver.com/gate.nhn?id=1...
# 4  http://search.shopping.naver.com/gate.nhn?id=1...
# 5  http://search.shopping.naver.com/gate.nhn?id=1...
# 6  http://search.shopping.naver.com/gate.nhn?id=1...
# 7  http://search.shopping.naver.com/gate.nhn?id=1...
# 8  http://search.shopping.naver.com/gate.nhn?id=8...
# 9  http://search.shopping.naver.com/gate.nhn?id=1...

# %%
search_result = get_search_result('shop', '몰스킨', 3, 2)
tmp2 = get_fields(search_result['items'])
tmp2
# Out:
# [2018-08-29 15:39:42.015386] Url Request Success
#                                     title lprice  hprice  \
# 0                           몰스킨 클래식 룰드 줄지  15690   40690
# 1      KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 2                       몰스킨 까이에 엑스라지 다이어리   8700   34100
# 3            몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 4                               몰스킨 와인 저널  28880       0
# 5                       몰스킨 2018 스누피 다이어리  12000       0
# 6  몰스킨 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162  19000       0
# 7         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   8990       0
# 8         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   9900       0
# 9           몰스킨 2018 / 위클리 / 블랙 소프트 / 라지L  14000       0
#
#                                                 link
# 0  http://search.shopping.naver.com/gate.nhn?id=7...
# 1  http://search.shopping.naver.com/gate.nhn?id=1...
# 2  http://search.shopping.naver.com/gate.nhn?id=1...
# 3  http://search.shopping.naver.com/gate.nhn?id=1...
# 4  http://search.shopping.naver.com/gate.nhn?id=1...
# 5  http://search.shopping.naver.com/gate.nhn?id=1...
# 6  http://search.shopping.naver.com/gate.nhn?id=1...
# 7  http://search.shopping.naver.com/gate.nhn?id=1...
# 8  http://search.shopping.naver.com/gate.nhn?id=8...
# 9  http://search.shopping.naver.com/gate.nhn?id=1...

# %%
result_mol = []

for n in range(1, 100, 10):
    search_result = get_search_result('shop', '몰스킨', n, 10)
    result_mol.append(get_fields(search_result['items']))
    
result_mol = pd.concat(result_mol)
# Out:
# [2018-08-29 15:41:44.910232] Url Request Success
# [2018-08-29 15:41:44.992589] Url Request Success
# [2018-08-29 15:41:45.081245] Url Request Success
# [2018-08-29 15:41:45.162995] Url Request Success
# [2018-08-29 15:41:45.246774] Url Request Success
# [2018-08-29 15:41:45.334105] Url Request Success
# [2018-08-29 15:41:45.432518] Url Request Success
# [2018-08-29 15:41:45.522929] Url Request Success
# [2018-08-29 15:41:45.610593] Url Request Success
# [2018-08-29 15:41:45.690397] Url Request Success

# %%
result_mol.head()
# Out:
#                                 title lprice  hprice  \
# 0                       몰스킨 클래식 룰드 줄지  15690   40690
# 1  KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 2                   몰스킨 까이에 엑스라지 다이어리   8700   34100
# 3        몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 4                           몰스킨 와인 저널  28880       0
#
#                                                 link
# 0  http://search.shopping.naver.com/gate.nhn?id=7...
# 1  http://search.shopping.naver.com/gate.nhn?id=1...
# 2  http://search.shopping.naver.com/gate.nhn?id=1...
# 3  http://search.shopping.naver.com/gate.nhn?id=1...
# 4  http://search.shopping.naver.com/gate.nhn?id=1...

# %%
result_mol = result_mol.reset_index(drop=True)
result_mol
# Out:
#                                      title lprice  hprice  \
# 0                            몰스킨 클래식 룰드 줄지  15690   40690
# 1       KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 2                        몰스킨 까이에 엑스라지 다이어리   8700   34100
# 3             몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 4                                몰스킨 와인 저널  28880       0
# 5                        몰스킨 2018 스누피 다이어리  12000       0
# 6   몰스킨 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162  19000       0
# 7          몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   8990       0
# 8          몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   9900       0
# 9            몰스킨 2018 / 위클리 / 블랙 소프트 / 라지L  14000       0
# 10                           몰스킨 클래식 룰드 줄지  15690   40690
# 11      KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 12                       몰스킨 까이에 엑스라지 다이어리   8700   34100
# 13            몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 14                               몰스킨 와인 저널  28880       0
# 15                       몰스킨 2018 스누피 다이어리  12000       0
# 16  몰스킨 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162  19000       0
# 17         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   8990       0
# 18         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   9900       0
# 19           몰스킨 2018 / 위클리 / 블랙 소프트 / 라지L  14000       0
# 20                           몰스킨 클래식 룰드 줄지  15690   40690
# 21      KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 22                       몰스킨 까이에 엑스라지 다이어리   8700   34100
# 23            몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 24                               몰스킨 와인 저널  28880       0
# 25                       몰스킨 2018 스누피 다이어리  12000       0
# 26  몰스킨 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162  19000       0
# 27         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   8990       0
# 28         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   9900       0
# 29           몰스킨 2018 / 위클리 / 블랙 소프트 / 라지L  14000       0
# ..                                     ...    ...     ...
# 70                           몰스킨 클래식 룰드 줄지  15690   40690
# 71      KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 72                       몰스킨 까이에 엑스라지 다이어리   8700   34100
# 73            몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 74                               몰스킨 와인 저널  28880       0
# 75                       몰스킨 2018 스누피 다이어리  12000       0
# 76  몰스킨 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162  19000       0
# 77         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   8990       0
# 78         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   9900       0
# 79           몰스킨 2018 / 위클리 / 블랙 소프트 / 라지L  14000       0
# 80                           몰스킨 클래식 룰드 줄지  15690   40690
# 81      KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 82                       몰스킨 까이에 엑스라지 다이어리   8700   34100
# 83            몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 84                               몰스킨 와인 저널  28880       0
# 85                       몰스킨 2018 스누피 다이어리  12000       0
# 86  몰스킨 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162  19000       0
# 87         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   8990       0
# 88         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   9900       0
# 89           몰스킨 2018 / 위클리 / 블랙 소프트 / 라지L  14000       0
# 90                           몰스킨 클래식 룰드 줄지  15690   40690
# 91      KM 몰스킨 클래식 룰드 줄지 소프트커버 라지 노트북 9788  19400       0
# 92                       몰스킨 까이에 엑스라지 다이어리   8700   34100
# 93            몰스킨 2017 위클리 18개월 그린 하드 다이어리  20000  228500
# 94                               몰스킨 와인 저널  28880       0
# 95                       몰스킨 2018 스누피 다이어리  12000       0
# 96  몰스킨 클래식 룰드 줄지 소프트커버 라지 9788-88370-7162  19000       0
# 97         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   8990       0
# 98         몰스킨 피너츠 데일리 2018 코랄오렌지 라지 55532   9900       0
# 99           몰스킨 2018 / 위클리 / 블랙 소프트 / 라지L  14000       0
#
#                                                  link
# 0   http://search.shopping.naver.com/gate.nhn?id=7...
# 1   http://search.shopping.naver.com/gate.nhn?id=1...
# 2   http://search.shopping.naver.com/gate.nhn?id=1...
# 3   http://search.shopping.naver.com/gate.nhn?id=1...
# 4   http://search.shopping.naver.com/gate.nhn?id=1...
# 5   http://search.shopping.naver.com/gate.nhn?id=1...
# 6   http://search.shopping.naver.com/gate.nhn?id=1...
# 7   http://search.shopping.naver.com/gate.nhn?id=1...
# 8   http://search.shopping.naver.com/gate.nhn?id=8...
# 9   http://search.shopping.naver.com/gate.nhn?id=1...
# 10  http://search.shopping.naver.com/gate.nhn?id=7...
# 11  http://search.shopping.naver.com/gate.nhn?id=1...
# 12  http://search.shopping.naver.com/gate.nhn?id=1...
# 13  http://search.shopping.naver.com/gate.nhn?id=1...
# 14  http://search.shopping.naver.com/gate.nhn?id=1...
# 15  http://search.shopping.naver.com/gate.nhn?id=1...
# 16  http://search.shopping.naver.com/gate.nhn?id=1...
# 17  http://search.shopping.naver.com/gate.nhn?id=1...
# 18  http://search.shopping.naver.com/gate.nhn?id=8...
# 19  http://search.shopping.naver.com/gate.nhn?id=1...
# 20  http://search.shopping.naver.com/gate.nhn?id=7...
# 21  http://search.shopping.naver.com/gate.nhn?id=1...
# 22  http://search.shopping.naver.com/gate.nhn?id=1...
# 23  http://search.shopping.naver.com/gate.nhn?id=1...
# 24  http://search.shopping.naver.com/gate.nhn?id=1...
# 25  http://search.shopping.naver.com/gate.nhn?id=1...
# 26  http://search.shopping.naver.com/gate.nhn?id=1...
# 27  http://search.shopping.naver.com/gate.nhn?id=1...
# 28  http://search.shopping.naver.com/gate.nhn?id=8...
# 29  http://search.shopping.naver.com/gate.nhn?id=1...
# ..                                                ...
# 70  http://search.shopping.naver.com/gate.nhn?id=7...
# 71  http://search.shopping.naver.com/gate.nhn?id=1...
# 72  http://search.shopping.naver.com/gate.nhn?id=1...
# 73  http://search.shopping.naver.com/gate.nhn?id=1...
# 74  http://search.shopping.naver.com/gate.nhn?id=1...
# 75  http://search.shopping.naver.com/gate.nhn?id=1...
# 76  http://search.shopping.naver.com/gate.nhn?id=1...
# 77  http://search.shopping.naver.com/gate.nhn?id=1...
# 78  http://search.shopping.naver.com/gate.nhn?id=8...
# 79  http://search.shopping.naver.com/gate.nhn?id=1...
# 80  http://search.shopping.naver.com/gate.nhn?id=7...
# 81  http://search.shopping.naver.com/gate.nhn?id=1...
# 82  http://search.shopping.naver.com/gate.nhn?id=1...
# 83  http://search.shopping.naver.com/gate.nhn?id=1...
# 84  http://search.shopping.naver.com/gate.nhn?id=1...
# 85  http://search.shopping.naver.com/gate.nhn?id=1...
# 86  http://search.shopping.naver.com/gate.nhn?id=1...
# 87  http://search.shopping.naver.com/gate.nhn?id=1...
# 88  http://search.shopping.naver.com/gate.nhn?id=8...
# 89  http://search.shopping.naver.com/gate.nhn?id=1...
# 90  http://search.shopping.naver.com/gate.nhn?id=7...
# 91  http://search.shopping.naver.com/gate.nhn?id=1...
# 92  http://search.shopping.naver.com/gate.nhn?id=1...
# 93  http://search.shopping.naver.com/gate.nhn?id=1...
# 94  http://search.shopping.naver.com/gate.nhn?id=1...
# 95  http://search.shopping.naver.com/gate.nhn?id=1...
# 96  http://search.shopping.naver.com/gate.nhn?id=1...
# 97  http://search.shopping.naver.com/gate.nhn?id=1...
# 98  http://search.shopping.naver.com/gate.nhn?id=8...
# 99  http://search.shopping.naver.com/gate.nhn?id=1...
#
# [100 rows x 4 columns]

# %%
import requests

client_id = "PPjV1s7bhkR6K7oR5qSG"
client_secret = "0uf4bSaSJC"

url = "https://openapi.naver.com/v1/vision/celebrity"

files = {'image': open('../data/face_detection_test_JH3.jpeg','rb')}


headers = {"X-Naver-Client-Id": client_id, "X-Naver-Client-Secret": client_secret}

response = requests.post(url, files=files, headers=headers)
rescode = response.status_code
if(rescode == 200):
    print(response.text)
    
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":721,"height":960},"faceCount":2},"faces":[{"celebrity":{"value":"김홍표","confidence":0.411627}},{"celebrity":{"value":"조연우","confidence":0.01}}]}

# %%
client_id = "PPjV1s7bhkR6K7oR5qSG"
client_secret = "0uf4bSaSJC"

url = "https://openapi.naver.com/v1/vision/celebrity"

files = {'image': open('../data/face_detection_test_PW.jpg','rb')}


headers = {"X-Naver-Client-Id": client_id, "X-Naver-Client-Secret": client_secret}

response = requests.post(url, files=files, headers=headers)
rescode = reponse.status_code
if(rescode == 200):
    print(response.text)
    
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":748,"height":1034},"faceCount":1},"faces":[{"celebrity":{"value":"윤민수","confidence":0.111414}}]}

# %%
url = "https://openapi.naver.com/v1/vision/face"

files = {'image': open('../data/face_detection_test_IU.jpg','rb')}


headers = {"X-Naver-Client-Id": client_id, "X-Naver-Client-Secret": client_secret}

response = requests.post(url, files=files, headers=headers)
rescode = reponse.status_code
if(rescode == 200):
    print(response.text)
    
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":914,"height":836},"faceCount":1},"faces":[{"roi":{"x":193,"y":192,"width":518,"height":518},"landmark":{"leftEye":{"x":320,"y":323},"rightEye":{"x":574,"y":288},"nose":{"x":459,"y":453},"leftMouth":{"x":392,"y":620},"rightMouth":{"x":571,"y":595}},"gender":{"value":"female","confidence":0.996178},"age":{"value":"17~21","confidence":0.469397},"emotion":{"value":"neutral","confidence":0.999103},"pose":{"value":"frontal_face","confidence":0.999678}}]}

# %%
url = "https://openapi.naver.com/v1/vision/face"

files = {'image': open('../data/face_detection_test_JH3.jpeg','rb')}


headers = {"X-Naver-Client-Id": client_id, "X-Naver-Client-Secret": client_secret}

response = requests.post(url, files=files, headers=headers)
rescode = response.status_code
if(rescode == 200):
    print(response.text)
    
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":721,"height":960},"faceCount":2},"faces":[{"roi":{"x":118,"y":324,"width":301,"height":301},"landmark":{"leftEye":{"x":189,"y":389},"rightEye":{"x":339,"y":388},"nose":{"x":273,"y":466},"leftMouth":{"x":203,"y":568},"rightMouth":{"x":336,"y":561}},"gender":{"value":"male","confidence":0.881371},"age":{"value":"22~26","confidence":0.103286},"emotion":{"value":"disgust","confidence":0.999867},"pose":{"value":"frontal_face","confidence":0.999436}},{"roi":{"x":572,"y":143,"width":33,"height":33},"landmark":{"leftEye":{"x":577,"y":153},"rightEye":{"x":593,"y":153},"nose":{"x":586,"y":161},"leftMouth":{"x":582,"y":168},"rightMouth":{"x":594,"y":169}},"gender":{"value":"female","confidence":0.998549},"age":{"value":"33~37","confidence":0.206453},"emotion":{"value":"smile","confidence":0.986857},"pose":{"value":"frontal_face","confidence":0.99223}}]}

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import numpy as np
# %matplotlib inline

# %%
img = mpimg.imread('../data/face_detection_test_JH3.jpeg')
imgplot = plt.imshow(img)

# %%
import json
detect_result = json.loads(response.text)
detect_result
# Out:
# {'info': {'size': {'width': 721, 'height': 960}, 'faceCount': 2},
#  'faces': [{'roi': {'x': 118, 'y': 324, 'width': 301, 'height': 301},
#    'landmark': {'leftEye': {'x': 189, 'y': 389},
#     'rightEye': {'x': 339, 'y': 388},
#     'nose': {'x': 273, 'y': 466},
#     'leftMouth': {'x': 203, 'y': 568},
#     'rightMouth': {'x': 336, 'y': 561}},
#    'gender': {'value': 'male', 'confidence': 0.881371},
#    'age': {'value': '22~26', 'confidence': 0.103286},
#    'emotion': {'value': 'disgust', 'confidence': 0.999867},
#    'pose': {'value': 'frontal_face', 'confidence': 0.999436}},
#   {'roi': {'x': 572, 'y': 143, 'width': 33, 'height': 33},
#    'landmark': {'leftEye': {'x': 577, 'y': 153},
#     'rightEye': {'x': 593, 'y': 153},
#     'nose': {'x': 586, 'y': 161},
#     'leftMouth': {'x': 582, 'y': 168},
#     'rightMouth': {'x': 594, 'y': 169}},
#    'gender': {'value': 'female', 'confidence': 0.998549},
#    'age': {'value': '33~37', 'confidence': 0.206453},
#    'emotion': {'value': 'smile', 'confidence': 0.986857},
#    'pose': {'value': 'frontal_face', 'confidence': 0.99223}}]}

# %%
detect_summary = detect_result['faces'][0]
detect_summary.keys()
# Out:
# dict_keys(['roi', 'landmark', 'gender', 'age', 'emotion', 'pose'])

# %%
detect_summary['roi']
# Out:
# {'x': 118, 'y': 324, 'width': 301, 'height': 301}

# %%
x, y, w, h = detect_summary['roi'].values()
x, y, w, h
# Out:
# (118, 324, 301, 301)

# %%
gender, gen_confidence = detect_summary['gender'].values()
gender, gen_confidence
# Out:
# ('male', 0.881371)

# %%
emotion, emotion_confidence = detect_summary['emotion'].values()
emotion, emotion_confidence
# Out:
# ('disgust', 0.999867)

# %%
age, age_confidence = detect_summary['age'].values()
age, age_confidence
# Out:
# ('22~26', 0.103286)

# %%
x, y, w, h = detect_summary['roi'].values()
gender, gen_confidence = detect_summary['gender'].values()
emotion, emotion_confidence = detect_summary['emotion'].values()
age, age_confidence = detect_summary['age'].values()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img)
rect_face = patches.Rectangle((x,y),w,h,
                              linewidth=5,
                              edgecolor='r',
                              facecolor='none')

ax.add_patch(rect_face)

annotation = gender + ' : ' + str(gen_confidence) + \
             '\n' + emotion + ' : ' + str(emotion_confidence) + \
             '\n' + age + ' : ' + str(age_confidence)

plt.figtext(0.25, 0.17, annotation, wrap=True, fontsize=17, color='red')
plt.show()

# %%
img = mpimg.imread('../data/face_detection_test_GP2.jpeg')
imgplot = plt.imshow(img)

# %%
url = "https://openapi.naver.com/v1/vision/face"

files = {'image': open('../data/face_detection_test_GP2.jpeg','rb')}


headers = {"X-Naver-Client-Id": client_id, "X-Naver-Client-Secret": client_secret}

response = requests.post(url, files=files, headers=headers)
rescode = reponse.status_code
if(rescode == 200):
    print(response.text)
    
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":1334,"height":1334},"faceCount":4},"faces":[{"roi":{"x":75,"y":886,"width":289,"height":289},"landmark":null,"gender":{"value":"female","confidence":0.990199},"age":{"value":"27~31","confidence":0.14998},"emotion":{"value":"neutral","confidence":0.99747},"pose":{"value":"false_face","confidence":0.664437}},{"roi":{"x":536,"y":427,"width":261,"height":261},"landmark":{"leftEye":{"x":593,"y":506},"rightEye":{"x":707,"y":480},"nose":{"x":662,"y":550},"leftMouth":{"x":625,"y":634},"rightMouth":{"x":742,"y":615}},"gender":{"value":"male","confidence":0.998954},"age":{"value":"35~39","confidence":0.0247286},"emotion":{"value":"neutral","confidence":0.99959},"pose":{"value":"frontal_face","confidence":0.998831}},{"roi":{"x":269,"y":351,"width":211,"height":211},"landmark":{"leftEye":{"x":324,"y":389},"rightEye":{"x":423,"y":402},"nose":{"x":364,"y":448},"leftMouth":{"x":313,"y":491},"rightMouth":{"x":404,"y":505}},"gender":{"value":"male","confidence":0.977702},"age":{"value":"35~39","confidence":0.125763},"emotion":{"value":"neutral","confidence":0.999915},"pose":{"value":"frontal_face","confidence":0.999613}},{"roi":{"x":1112,"y":725,"width":221,"height":225},"landmark":{"leftEye":{"x":1156,"y":771},"rightEye":{"x":1258,"y":768},"nose":{"x":1188,"y":813},"leftMouth":{"x":1160,"y":875},"rightMouth":{"x":1248,"y":884}},"gender":{"value":"female","confidence":0.996365},"age":{"value":"24~28","confidence":0.467661},"emotion":{"value":"sad","confidence":0.997851},"pose":{"value":"frontal_face","confidence":0.993716}}]}

# %%
detect_result = json.loads(response.text)
detect_result
# Out:
# {'info': {'size': {'width': 1334, 'height': 1334}, 'faceCount': 4},
#  'faces': [{'roi': {'x': 75, 'y': 886, 'width': 289, 'height': 289},
#    'landmark': None,
#    'gender': {'value': 'female', 'confidence': 0.990199},
#    'age': {'value': '27~31', 'confidence': 0.14998},
#    'emotion': {'value': 'neutral', 'confidence': 0.99747},
#    'pose': {'value': 'false_face', 'confidence': 0.664437}},
#   {'roi': {'x': 536, 'y': 427, 'width': 261, 'height': 261},
#    'landmark': {'leftEye': {'x': 593, 'y': 506},
#     'rightEye': {'x': 707, 'y': 480},
#     'nose': {'x': 662, 'y': 550},
#     'leftMouth': {'x': 625, 'y': 634},
#     'rightMouth': {'x': 742, 'y': 615}},
#    'gender': {'value': 'male', 'confidence': 0.998954},
#    'age': {'value': '35~39', 'confidence': 0.0247286},
#    'emotion': {'value': 'neutral', 'confidence': 0.99959},
#    'pose': {'value': 'frontal_face', 'confidence': 0.998831}},
#   {'roi': {'x': 269, 'y': 351, 'width': 211, 'height': 211},
#    'landmark': {'leftEye': {'x': 324, 'y': 389},
#     'rightEye': {'x': 423, 'y': 402},
#     'nose': {'x': 364, 'y': 448},
#     'leftMouth': {'x': 313, 'y': 491},
#     'rightMouth': {'x': 404, 'y': 505}},
#    'gender': {'value': 'male', 'confidence': 0.977702},
#    'age': {'value': '35~39', 'confidence': 0.125763},
#    'emotion': {'value': 'neutral', 'confidence': 0.999915},
#    'pose': {'value': 'frontal_face', 'confidence': 0.999613}},
#   {'roi': {'x': 1112, 'y': 725, 'width': 221, 'height': 225},
#    'landmark': {'leftEye': {'x': 1156, 'y': 771},
#     'rightEye': {'x': 1258, 'y': 768},
#     'nose': {'x': 1188, 'y': 813},
#     'leftMouth': {'x': 1160, 'y': 875},
#     'rightMouth': {'x': 1248, 'y': 884}},
#    'gender': {'value': 'female', 'confidence': 0.996365},
#    'age': {'value': '24~28', 'confidence': 0.467661},
#    'emotion': {'value': 'sad', 'confidence': 0.997851},
#    'pose': {'value': 'frontal_face', 'confidence': 0.993716}}]}

# %%
detect_result['faces']
# Out:
# [{'roi': {'x': 75, 'y': 886, 'width': 289, 'height': 289},
#   'landmark': None,
#   'gender': {'value': 'female', 'confidence': 0.990199},
#   'age': {'value': '27~31', 'confidence': 0.14998},
#   'emotion': {'value': 'neutral', 'confidence': 0.99747},
#   'pose': {'value': 'false_face', 'confidence': 0.664437}},
#  {'roi': {'x': 536, 'y': 427, 'width': 261, 'height': 261},
#   'landmark': {'leftEye': {'x': 593, 'y': 506},
#    'rightEye': {'x': 707, 'y': 480},
#    'nose': {'x': 662, 'y': 550},
#    'leftMouth': {'x': 625, 'y': 634},
#    'rightMouth': {'x': 742, 'y': 615}},
#   'gender': {'value': 'male', 'confidence': 0.998954},
#   'age': {'value': '35~39', 'confidence': 0.0247286},
#   'emotion': {'value': 'neutral', 'confidence': 0.99959},
#   'pose': {'value': 'frontal_face', 'confidence': 0.998831}},
#  {'roi': {'x': 269, 'y': 351, 'width': 211, 'height': 211},
#   'landmark': {'leftEye': {'x': 324, 'y': 389},
#    'rightEye': {'x': 423, 'y': 402},
#    'nose': {'x': 364, 'y': 448},
#    'leftMouth': {'x': 313, 'y': 491},
#    'rightMouth': {'x': 404, 'y': 505}},
#   'gender': {'value': 'male', 'confidence': 0.977702},
#   'age': {'value': '35~39', 'confidence': 0.125763},
#   'emotion': {'value': 'neutral', 'confidence': 0.999915},
#   'pose': {'value': 'frontal_face', 'confidence': 0.999613}},
#  {'roi': {'x': 1112, 'y': 725, 'width': 221, 'height': 225},
#   'landmark': {'leftEye': {'x': 1156, 'y': 771},
#    'rightEye': {'x': 1258, 'y': 768},
#    'nose': {'x': 1188, 'y': 813},
#    'leftMouth': {'x': 1160, 'y': 875},
#    'rightMouth': {'x': 1248, 'y': 884}},
#   'gender': {'value': 'female', 'confidence': 0.996365},
#   'age': {'value': '24~28', 'confidence': 0.467661},
#   'emotion': {'value': 'sad', 'confidence': 0.997851},
#   'pose': {'value': 'frontal_face', 'confidence': 0.993716}}]

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img)

for each in detect_result['faces']:
    x, y, w, h = each['roi'].values()
    gender, gen_confidence = each['gender'].values()
    emotion, emotion_confidence = each['emotion'].values()
    age, age_confidence = each['age'].values()
    
    rect_face = patches.Rectangle((x,y),w,h,
                              linewidth=5,
                              edgecolor='r',
                              facecolor='none')
    
    ant_letter = gender[0] + ', ' + emotion + ', ' + age
    
    plt.text(x,y-10, ant_letter, size = 16, color='red')
    ax.add_patch(rect_face)
    
plt.show()
